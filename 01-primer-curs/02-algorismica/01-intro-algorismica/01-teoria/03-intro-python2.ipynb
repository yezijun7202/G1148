# %% [markdown]
# Aquest notebook forma part dels continguts teòrics dels problemes de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a></p>
#
# Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>

# %% [markdown]
# # 📘 Introducció a Python 📘 Notebook I

# %% [markdown]
# A continuació es mostren operacions bàsiques i tipus de dades a Python per familiaritzar-se una mica amb aquest llenguatge.

# %% [markdown]
#  ## 🧠 Operacions bàsiques
#
# En les cel·les següents apareixen algunes expressions bàsiques de Python. Executa cada cel·la per veure'n el resultat.
#
# Alguns operadors i funcions habituals són:
#
# - `+`: suma;
# - `-`: resta;
# - `*`: multiplicació;
# - `/`: divisió;
# - `//`: divisió entera;
# - `%`: residu de la divisió;
# - `**`: potència;
# - `abs()`: valor absolut.

# %% [markdown]
#  ## 🧠 Mostrar resultats a pantalla: `print()`
#
# En un notebook Jupyter, el resultat d'una expressió situada al final d'una cel·la es mostra automàticament.
#
# Quan volem mostrar explícitament informació, mostrar diversos resultats o combinar text i valors, utilitzem la funció `print()`.
#
# Per exemple:
#
# ```python
# print("Hola")
# print(8 + 7)

# %%
print("Hola, què tal?")
print(8 + 7)
# Out:
# Hola, què tal?
# 15

# %% [markdown]
#  ## 🧠 Expressions matemàtiques amb enters

# %%
# Sumar dos enters
3 + 5
# Out:
# 8

# %%
# Restar dos enters
3 - 6
# Out:
# -3

# %%
# Multiplicar dos enters
2 * 4
# Out:
# 8

# %%
# Dividir dos enters divisibles. Sempre retorna un float
12 / 3
# Out:
# 4.0

# %%
# Dividir dos enters no divisibles. Sempre retorna un float
12 / 15
# Out:
# 0.8

# %%
# Residu de la divisió (mòdul)
12 % 15
# Out:
# 12

# %%
# Potències
2 ** 5
# Out:
# 32

# %%
# Arrel quadrada
25 ** 0.5
# Out:
# 5.0

# %% [markdown]
#  ## 🧠 Expressions matemàtiques amb nombres decimals
#
# Els nombres decimals es representen amb el tipus `float`.
#
# Podem combinar nombres `int` i `float` en una mateixa expressió. En moltes
# operacions aritmètiques entre un `int` i un `float`, el resultat serà de
# tipus `float`.
#
# Per exemple:
#
# `3 + 2.5`
#
# produeix:
#
# `5.5`

# %%
# Exemple 1
3.2 + 1.0
# Out:
# 4.2

# %%
# Combinació d'operacions
((5.2 / 6.1) - 2.5 * 2) ** 2
# Out:
# 17.202096210696048

# %% [markdown]
# ## ✍️ 1. Exercici 1: càlculs pagaments
#
# Ens venen un ordinador per **700 €** i hi hem d'afegir un **21% d'IVA**.
#
# 1. Quin serà el preu final?
# 2. Si l'import final es reparteix entre dos germans, quant haurà de pagar
#    cadascun?
#
# Escriu les expressions Python necessàries i mostra els resultats.

# %% [markdown]
# ## 🧠 Expressions lògiques
#
# Python representa els valors lògics amb el tipus `bool`, que pot prendre
# dos valors:
#
# - `True`
# - `False`
#
# Els principals operadors lògics són:
#
# - `and`
# - `or`
# - `not`
#
# Els operadors de comparació també produeixen valors booleans:
#
# `<`, `>`, `<=`, `>=`, `==` i `!=`.

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
not True
# Out:
# False

# %%
# Cal tenir clar l'ordre en que s'avaluen
True and False or True
# Out:
# True

# %%
# Condicions que resulten en valors lògics
4 < 5
# Out:
# True

# %%
5 >= 7
# Out:
# False

# %%
# Per comparar dos elements, s'utilitza el doble igual
# El signe igual simple es reserva per a les assignacions
5 == 5
# Out:
# True

# %% [markdown]
# ## ✍️ 2. Exercici 2: Expressions lògiques
#
# Escriu amb Python les expressions lògiques següents:
#
# 1. `5` és més gran que `3` **i** `7` és més petit que `9`.
# 2. `8` és igual a `4 + 4`.
# 3. No és cert que `7` sigui diferent de `3.5 * 2`.
#
# Executa-les i comprova quin valor booleà retorna cadascuna.

# %% [markdown]
# ## 🧠 Cadenes de caràcters (`str`)
#
# El text es representa en Python amb el tipus `str`.
#
# Una cadena és una seqüència immutable de caràcters Unicode. Pot contenir,
# per exemple, lletres, números, espais, signes de puntuació i caràcters de
# molts sistemes d'escriptura.
#
# Podem delimitar una cadena tant amb cometes simples com amb cometes dobles:
#
# ```python
# "Hola"
# 'Hola'

# %%
# Podem concatenar cadenes amb la suma
'Hola' + "Món"
# Out:
# 'HolaMón'

# %%
# Podem repetir cadenes amb el producte
"Qualsevol text " * 10
# Out:
# 'Qualsevol text Qualsevol text Qualsevol text Qualsevol text Qualsevol text Qualsevol text Qualsevol text Qualsevol text Qualsevol text Qualsevol text '

# %%
# Podem saber la longitud d'una cadena de caràcters amb la funció len
len("Hola Món")
# Out:
# 8

# %%
# Podem accedir a un caràcter de la cadena amb la seva posició
# Es comença a comptar per 0
"abcdefghijklmnopqrstuvwxyz"[3]
# Out:
# 'd'

# %%
# Podem accedir a una part de la cadena (subcadenes) 
# indicant el caràcter per el que començar i pel que acabar (que no s'inclou). 
# Aquesta transformació es coneix amb el nom "slicing"
"abcdefghijklmnopqrstuvwxyz"[3:5]
# Out:
# 'de'

# %%
# Si volem començar des del principi, no cal posar el zero
"abcdefghijklmnopqrstuvwxyz"[:3]
# Out:
# 'abc'

# %%
# Si volem agafar fins al final, no cal posar el final
"abcdefghijklmnopqrstuvwxyz"[15:]
# Out:
# 'pqrstuvwxyz'

# %%
# Podem utilitzar índex negatius per comptar des del final. 
# Per exemple, per agafar el tercer caràcter pel final:
"abcdefghijklmnopqrstuvwxyz"[-3]
# Out:
# 'x'

# %%
# O per agafar els tres últims caràcters:
"abcdefghijklmnopqrstuvwxyz"[-3:]
# Out:
# 'xyz'

# %%
# Si no posem ni inici ni fi, ho agafem tot
"abcdefghijklmnopqrstuvwxyz"[:]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
# Les cadenes tenen alguns mètodes que permeten fer-hi conversions.
# Per exemple, el mètode "upper" transforma la cadena a majúscules
"aBc".upper()
# Out:
# 'ABC'

# %%
# El mètode lower transforma la cadena a minúscules
"ABCd".lower()
# Out:
# 'abcd'

# %% [markdown]
# ## ✍️ 3. Exercici 3: Cadenes de caràcters
#
# 1. Crea una cadena concatenant el teu nom i el teu cognom.
# 2. A partir de la cadena següent:
#
#    `Domino Python Vaig fent amb Python Em costa Python`
#
#    selecciona'n una part mitjançant *slicing*.
# 3. Repeteix tres vegades la subcadena seleccionada.
# 4. Mostra el teu nom complet en majúscules utilitzant `upper()`.

# %% [markdown]
# ### Tipus de dades
#
# Python diferencia diferents tipus de dades. Alguns dels que utilitzarem
# més sovint són:
#
# - `int`: nombres enters;
# - `float`: nombres decimals;
# - `str`: cadenes de caràcters;
# - `bool`: valors booleans.
#
# Les dades es poden guardar en variables.
#
# Python és un llenguatge de **tipatge dinàmic**: no és obligatori declarar
# el tipus d'una variable abans d'utilitzar-la.
#
# Tot i això, Python permet afegir **anotacions de tipus**. En aquesta
# assignatura les utilitzarem sistemàticament perquè fan més explícit el
# tipus de dada que esperem:
#
# ```python
# edat: int = 20
# preu: float = 12.5
# nom: str = "Anna"
# actiu: bool = True

# %%
# Python permet crear variables sense indicar-ne explícitament el tipus.
# En aquesta assignatura, però, utilitzarem anotacions de tipus.
a = 5  # no fer a l'assignatura!
type(a)
# Out:
# int

# %%
b:str = 'a'
type(b)
# Out:
# str

# %%
c:float = 3.0
type(c)
# Out:
# float

# %% [markdown]
# ## 🧠 Barrejant cadenes i variables: f-strings
#
# És habitual construir cadenes que incorporen els valors de variables o
# expressions.
#
# Una manera clara de fer-ho és utilitzar **f-strings** (*formatted string
# literals*).
#
# Escric `f` davant de la cadena i col·loco les expressions que vull
# incorporar entre claus `{}`:
#
# ```python
# nom: str = "Anna"
# edat: int = 20
#
# print(f"Em dic {nom} i tinc {edat} anys")
# ```
#
# Dins de `{}` també podem escriure expressions:
#
# ```python
# print(f"L'any que ve tindré {edat + 1} anys")
# ```

# %%
# Creem una cadena de caràcters amb els valors de les variables a1 i a2.
a1: int = 25
a2: bool = False

print(f"El valor d'a1 és {a1} i el d'a2 és {a2}")
# Out:
# El valor d'a1 és 25 i el d'a2 és False

# %% [markdown]
# **Exercici**: crea una variable amb el vostre nom i una altra amb la vostra edat, definiu-les amb el tipus explícit. Mostra per pantalla un text que digui "Em dic XX i tinc XX anys".

# %% [markdown]
# ## 🧠 Llistes
#
# Les llistes (`list`) permeten agrupar diversos valors en una mateixa
# estructura.
#
# Es defineixen utilitzant **claudàtors** `[` i `]`:
#
# `[1, 2, 3]`
#
# Les llistes són ordenades i mutables: podem consultar, modificar, afegir
# o eliminar elements.

# %%
# Llista amb 3 valors
[1, 2, 3]
# Out:
# [1, 2, 3]

# %%
# Les llistes tenen tipus list.
nombres: list[int] = [1, 2, 3, 4, 5]
type(nombres)
# Out:
# list

# %%
# Les llistes poden contenir elements de tipus diferents.
valors: list[object] = ["gat", True, 3, 4.5]

# %% [markdown]
# Amb les llistes podem aplicar moltes de les operacions que hem vist amb les cadenes de caràcters.

# %%
# Slicing
nombres[:]
# Out:
# [1, 2, 3, 4, 5]

# %%
# Selecció d'un element comptant des del final
nombres[-1]
# Out:
# 5

# %%
# Slicing parcial
nombres[2:4]
# Out:
# [3, 4]

# %%
# Concatenació
[1, 2, 3] + [4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
# Mostrem una llista
print([1, 2, 3, 4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Podem obtenir la longitud d'una llista amb la funció len
len([1, 2, 3, 4, 5])
# Out:
# 5

# %% [markdown]
# ## ✍️ 4. Exercici 4: Treball amb cadenes i llistes
#
# A partir de la frase "Algorísmica Programació Àlgebra" creeu una llista amb cada paraula i finalment mostreu per pantalla el primer element de la llista.

# %% [markdown]
# ## 🧠 Creació de llistes a partir d'altres iterables
#
# Podem crear llistes a partir d'altres objectes iterables, com ara
# `range` o les cadenes de caràcters.
#
# Per fer la conversió utilitzem la funció `list()`.
#
# Per exemple:
#
# `list(range(5))`
#
# crea una llista amb els nombres generats per `range(5)`.

# %%
# A partir d'una cadena obtenim una llista amb cadascun dels caràcters.
list("Hola Món")
# Out:
# ['H', 'o', 'l', 'a', ' ', 'M', 'ó', 'n']

# %%
# split() divideix una cadena en una llista de subcadenes.
# Sense separador, divideix pel whitespace i agrupa separadors consecutius.
"Hola Món".split()
# Out:
# ['Hola', 'Món']

# %%
# Si li indiquem un caràcter a split, separa per aquest caràcter
"Codi-Secret-AX-897".split("-")
# Out:
# ['Codi', 'Secret', 'AX', '897']

# %% [markdown]
# ## ✍️ 5. Exercici 5: Treball amb cadenes i llistes
#
# 1. Crea una llista amb els nombres enters de `100` a `110`, ambdós inclosos.
# 2. A partir de la cadena:
#
#    `123.456.789`
#
#    crea una llista separant-ne els elements pels punts (`.`).

# %% [markdown]
# Aquesta llista de problemes i solucions ha estat preparada amb l'ajut de ChatGPT 3.5, i revisada i adaptada per Mireia Ribera. I ha estat revisada a l'agost de 2026, amb l'ajut de Copilot.
