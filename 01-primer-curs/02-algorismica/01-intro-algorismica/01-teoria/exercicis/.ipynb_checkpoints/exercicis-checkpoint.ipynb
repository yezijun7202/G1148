# %%
# Primer crearem una funció que retorni la mitjana de les edats
 
def mitjana(llista_edats: list[int]) -> float:

    sumatori_edats: int = 0
    i: int = 0
    nombre_casos = len(llista)

    
    # volem sumar cada terme de la llista per obtenir un valor total per calcular la mitjana
    while i < nombre_casos:
        sumatori_edats += llista_edats[i] # cada terme s'afegirà dins d'una variable entera
        i += 1

    mitjana: float = sumatori_edats/nombre_casos

    return mitjana

print(mitjana([2,2,2,2])) # hauria de donar 2
print(mitjana([4,3,2,1])) # hauria de donar 2.5


# Ara crearem una funció que calcula la desviació estàndard de les edats

# Per calcular la desviació hem de calcular:
# 1. Sumatori (edatX - mitjana)^2 (edatX vol dir cada edat del grup)
# 2. Resultat del pas 1 / Nombre de casos
# 3. Arrel (Resultat pas 2)
# 4. Retornar desviació (float) 

def desviacio(llista_edats:list[int], mitjana: float) -> float:

    # Volem operar per a cada terme (edat) de la mateixa manera per després fer el sumatori

    i: int = 0
    nombre_casos = len(llista)
    sumatori_calcul: int = 0 # Volem emmagatzemmar el sumatori del pas 1 en una variable d'enters

    while i < nombre_casos:

        calcul: float = (llista_edats[i] - mitjana) ** 2 
        sumatori_calcul += calcul
        i += 1

    # Ara que tenim el sumatori del pas 1 procedim al pas 2,3,4

    desviacio_edats: float = (sumatori_calcul/nombre_casos)**0.5

    return desviacio_edats


print(desviacio([4,3,2,1],2.5))
# Out:
# 2.0
# 2.5
# 1.118033988749895

# %%
def mitjana_desviacio_edats() -> None:

    # demanaré les edats d'un grup familiar
    # faré una llista i un for iteratiu per preguntar per tots els membres del grup la seva edat

    llista_edats: list[int] = []
    
    for membre in ["pare", "mare", "germà", "germana"]:

        # input retorna un str, llavors transformem la cadena en enter i l'afegim dins la llista
        llista_edats.append(int(input(f"Introdueix l'edat del teu/va {membre}: ")))

    # ara vull calcular la mitjana de les edats
    # primer hauré de sumar els valors enters de cada terme de la llista per despres dividir entre el nombre de casos
    # print (llista_edats)
    
    suma_edats: int = 0
    nombre_casos: int = len(llista_edats)
    i: int = 0

    while i < nombre_casos:

        suma_edats += llista_edats[i]
        i += 1

    # print(suma_edats)

    mitjana: int = suma_edats / nombre_casos

    # ara vull calcular la desviació estàndard
    # 1. fem el sumatori de l'operació (edatX - mitjana)^2
    # 2. dividim (resultat pas 1)/nombre casos
    # 3. arrel quadrada (resultat pas 2)

    # per calcular el sumatori fem una mateixa operacio per a cada edat dins la llista

    j: int = 0
    sumatori_calcul: float = 0
    
    while j < nombre_casos:
        
        calcul: float = (llista_edats[j] - mitjana) ** 2
        sumatori_calcul += calcul   
        j += 1

    desviacio: float = (sumatori_calcul/nombre_casos) ** 0.5
    
    
    print(f"La mitjana d'edat és {mitjana} i la desviació estàndard és {desviacio}.")        
        
        
mitjana_desviacio_edats()
# Out:
# Introdueix l'edat del teu/va pare:  4
# Introdueix l'edat del teu/va mare:  3
# Introdueix l'edat del teu/va germà:  2
# Introdueix l'edat del teu/va germana:  1
# La mitjana d'edat és 2.5 i la desviació estàndard és 1.118033988749895.

# %%
Donat  4 3 2 1 -> 10 m(10) = 2.5

dado n = 4

(4 - 2.5)^2 = 2.25
(3 - 2.5)^2 = 0.25
(2 - 2.5)^2 = 0.25
(1 - 2.5)^2 = 2.25

sumatori = 2.25*2 + 0.25*2 = 5

5/n = 5/4 = 1,25

(1,25) ** 0,5
# Out:
#   Cell In[70], line 1
#     4 3 2 1 -> 10 m(10) = 2.5
#       ^
# SyntaxError: invalid syntax
