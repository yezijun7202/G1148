# %% [markdown]
# Aquest notebook forma part dels continguts teòrics dels problemes de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a></p>Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>

# %%
from typing import Any

# %% [markdown]
# # <span class="tema">Introducció a la programació</span><br/> 📘Codi de les transparències

# %% [markdown]
# ## 🧠 Python: Instrucció, variables, literals i expressions

# %%
# Això és un comentari: el programa no ho executa

# Instrucció: assignem un valor a una variable
edat: int = 25 # 'edat' és la variable, int vol dir integer i és el tipus, 25 és un literal (valor concret que fiquem en el codi font) 

# Una altra instrucció: imprimir per pantalla
print("Hola món!") # "Hola món!" és un literal de text (string o cadena)

# Expressió: suma d'una variable i un literal
nova_edat: int = edat + 5 # 'edat + 5' és una expressió que dona com a resultat 30

# Els operadors són +, -, *, /, // (divisió entera), ** (potència), % (mòdul)

# Mostrar el resultat
print("D'aquí 5 anys tindràs:", nova_edat)

# %% [markdown]
# ## 🧠 Python: crida de funcions

# %%
# Definició de la funció “area_quadrat”
def area_quadrat(costat:int) -> int:
    return costat**2

area_quadrat(5)


def sum(a:int, b:int) -> int: # Definició d'una funció "sumar" amb paràmetres (informació que rep una funció per fer-la servir) a i b
    return a + b # Retorna el resultat d'operar per addició els paràmetres

def dif(a:int, b:int) -> int: # Definició d'una funció "diferència" amb paràmetres a i b (són distintes que les de la funció "suma")
    return a - b # Retorna el resultat d'operar per diferència els paràmetres

def sumdif(a:int, b:int) -> int: # Definició d'una funció "suma i diferència"
    s:int = sum(a, b) # Creació d'una variable entera que pren com a valor la funció "suma" amb els arguments a i b
    # arguments: informació que es passa a la funció cridada (per tal d'assignar els valors dels paràmetres d'aquella funció) 
    d:int = dif(a, b)
    return s, d # Retorn de les variables s i d


a:int = 3 # Assignació d'una variable a (enter)
b:int = 3
print(sumdif(a, b)) # Mostrar per pantalla el resultat de la crida de funció "suma i diferència"

# %% [markdown]
# ## 🧠 Python: definir (def), cridar, mostrar resultats(print) , retornar resultats(return)

# %%
def suma(a: int, b: int) -> int:    # només definim, no executem
    print("la suma és ", a+b)
    return a + b

c: int = suma(5,7) # cridem la funció, c pren el valor del return

def dos_valors(a: int) -> tuple[int, int]: # tuple: agrupa diversos elements en un objecte
    return a, a+2 

d: int
e: int
d, e = dos_valors(4) # cridem la funció, d i e prenen el valor del return
# d i e desempaqueten la tupla formada per (a, a+2), on d = a i e = a+2
print(c,d,e)
# Out:
# la suma és  12
# 5 4 6

# %% [markdown]
# ## 🧠 Python: funció i mètode

# %%
# 1️⃣ FUNCIÓ: bloc de codi que retorna un resultat
def suma(a: int, b: int) -> int:
    return a + b

resultat: int = suma(3, 4)                        # Crida

# 2️⃣ MÈTODE: forma part d’un objecte o tipus (pots entendre'l com una funció específica)
text: str = "hola món"
majuscules: str = text.upper() # .upper() és el mètode

print("Text en majúscules ", majuscules)

# 3️⃣ FUNCIÓ SENSE RETORN: codi que fa alguna cosa però no retorna cap valor

def saluda() -> None:
    print("Hola! Encantat de conèixer-te!")    # Només fa una acció, no retorna res

saluda()                                       # Crida la funció, però no retorna res

# 4️⃣ FUNCIÓ DEL LLENGUATGE: són funcions de Python, no les definim nosaltres

len(text)
# len retorna la llargada en caràcters d'una cadena de caràcters.

# %% [markdown]
# ## 🧠 Python: paràmetre, crida o invocació

# %%
# 1️⃣ Definim una funció amb dos paràmetres
def suma(a: int, b: int) -> int:
    return a + b

# 2️⃣ Definim una funció sense paràmetres (funció que no necessita informació de fora)
def missatge() -> str:
    return "Hola!"

resultat1:int = suma(3, 4)          # passem 3 i 4 directament
print("Cas 1:", resultat1) 

x: int = 10
y: int = 5
resultat2: int = suma(x, y)         # passem el contingut de x i y
print("Cas 2:", resultat2) 

text: str = missatge()              # no necessita informació extra
print("Cas 3:", text)
# Out:
# Cas 1: 7
# Cas 2: 15
# Cas 3: Hola!

# %% [markdown]
# ## 🧠 Python: assignacions

# %%
# --- ASSIGNACIONS AMB LITERALS ---
numero: int = 10                   # enter
preu: float = 19.99                # nombre decimal
nom: str = "Maria"                 # text (string)
es_major: bool = True              # booleà

# --- ASSIGNACIONS AMB EXPRESSIONS ---
suma: int = 5 + 3                  # resultat = 8
producte: int = numero * 2         # resultat = 20
preu_final: float = preu * 1.21    # aplica IVA
nom_complet: str = nom + " López"  # concatenació
gran: bool = numero > 5            # comparació

# --- ASSIGNACIÓ AMB CRIDA A FUNCIÓ ---
longitud_nom: int = len(nom) 
# len() retorna la longitud de la cadena
valor_abs: int = abs(-42) 
# abs() retorna el valor absolut
maxim: int = max(10, 3, 25) 
# màxim de tres valors

# --- ASSIGNACIÓ MÚLTIPLE ---
x: int                             # tipus primer (s'espera que la variable x tingui un valor de tipus enter)
# funciona semblant a una declaració, tot i que és més precís dir que es tracta d'una anotació
y: int # pots assignar un altre tipus de valor a la variable (no et sortirà error però contradiu amb l'anotació)
x, y = 1, 2                        # assigna 1 a x i 2 a y

a: str                             # tipus primer
b: str
c: str
a, b, c = "A", "B", "C"

# %% [markdown]
# ## 🧠 Python: assignacions d’entrada i conversions

# %%
# --- TEXT (string) ---
nom1: str = input("Introdueix el teu nom: ")
nom2: str = eval(input("Introdueix el teu nom entre cometes: ")) # eval() interpreta el text com una expressió python
# expressió: fragment de codi que s'avalua i produeix un valor
# ex. a = "3 * 2" llavors eval(a) = 6 (ja que avalua l'expressió i mostra el resultat de la multiplicació)

# --- ENTER (int) amb conversió directa ---
edat1: int = int(input("Introdueix la teva edat: ")) 
edat2: int = eval(input("Introdueix la teva edat: "))

# --- DECIMAL (float) amb conversió directa ---
altura1: float = float(input("Introdueix la teva altura en metres: "))
altura2: float = eval(input("Introdueix la teva altura en metres: "))

print(nom1, nom2, edat1, edat2, altura1, altura2)
# Out:
# Introdueix el teu nom:  z
# Introdueix el teu nom entre cometes:  "z"
# Introdueix la teva edat:  19
# Introdueix la teva edat:  "19"
# Introdueix la teva altura en metres:  1.72
# Introdueix la teva altura en metres:  "1.72"
# z z 19 19 1.72 1.72

# %% [markdown]
# ## 🧠 Python: iteracions for: range(start (0), stop, step (1))

# %%
# Recorregut sobre una llista
colors: list[str] = ["vermell", "blau", "verd"]
for color in colors:
    print(color)

# Recorregut sobre una paraula
for lletra in "Hola":
    print(lletra)

# Amb range(): números del 0 al 4
for i in range(5):
    print(i)

# Amb range(): del 2 al 10 saltant de 2 en 2
for i in range(2, 11, 2):
    print(i)
# Out:
# vermell
# blau
# verd
# H
# o
# l
# a
# 0
# 1
# 2
# 3
# 4
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ## 🧠 Python: iteracions while

# %%
# Demanem un número fins que sigui positiu
num: int = int(input("Introdueix un número positiu: "))
while num <= 0:
    num = int(input("Introdueix un número positiu: "))
print("Has introduït:", num)
# Out:
# Introdueix un número positiu:  -2
# Introdueix un número positiu:  0
# Introdueix un número positiu:  1
# Has introduït: 1

# %% [markdown]
# ## 🧠 Python: condicionals (estructures de control)

# %%
edat: int = 20

if edat < 18: # comprova la primera condició
    print("Menor d'edat")
elif edat < 65:  # opcionals, 0 o tants com vulguem
    # comprova la condició si les anteriors eren falses
    print("Adult")
else: # només s'executa si cap de les condicions és certa
    print("Sènior")
# Out:
# Adult

# %% [markdown]
# ## 🧪 Python: solucions d'IA (amb errors!)

# %%
def percentatge(part: float, total: float) -> float:
    """Retorna el percentatge que representa 'part' sobre 'total'"""
    return part / total * 100

def es_major_edat(edat: int) -> bool:
    """Comprova si una persona és major d'edat"""
    return edat > 18

def text_a_majuscules(text: str) -> str:
    """Converteix un text a majúscules"""
    majuscules = text.upper() # text.upper() retorna una nova cadena en majúscules, la qual requereix assignació d'una variable
    return majuscules # o també funciona si retornem directament "text.upper()", ja que retorna la nova cadena sense assignar variable

print(percentatge(10, 50))
print(es_major_edat(19))
print(text_a_majuscules("hola"))
# Out:
# 20.0
# True
# HOLA

# %% [markdown]
# ## 🧠 Python: operadors booleans

# %%
a:bool = True
b:bool = False
c:bool = a and b 
print(c) # True and False = False (no pot ser cert a i b)
print(a and b or c) # (True and False) or True = False or False = False (pot ser cert b o c)
print(a or (not b) and c) # True or [(True) and False] = True or False = True

# Jerarquia d'operadors lògics: not > and > or
# Out:
# False
# False
# True

# %% [markdown]
# ## 🧠 Python: cadenes de caràcters

# %%
# Com es guarden les cadenes de caràcters a l'ordinador
a = 'Hola'
print(a,b) # b pren l'últim valor assignat
type(a)
s = "Hello Bob"
x = 2
print(s[0], s[x], s[8-2])
# Out:
# Hola False
# H l B

# %%
# Les cadenes són immutables. El següent codi donarà error

paraula = "hola"
# paraula[0] = "c"  # Error 

# Immutable vol dir que un cop creada la cadena no podem modificar els elements individuals
# Podem modificar el seu valor però no un sol caràcter o dos o més...

paraula = "c" + paraula[1:] # Això és una expressió python, llavors funciona perquè s'avalua l'expressió i es dona un nou valor

print (paraula)
# Out:
# cola

# %%
# Quan demanem dades a l'usuari sempre rebem cadenes de caràcters
nom = input("Quin és el teu nom?")
print(type(nom)) # str
edat = int(input("Quina és la teva edat?"))
# Out:
# Quin és el teu nom? Zijun
# <class 'str'>
# Quina és la teva edat? 19

# %%
# Codificació: dins l'ordinador cada caràcter té un codi associat
print(chr(65)) # agafa un nombre enter com a codi Unicode i representa el caràcter corresponent
print(ord("A")) # agafa el caràcter corresponent i mostra el codi Unicode
print(chr(20320))
# Out:
# A
# 65
# 你

# %%
# Mètodes de string, operadors i funcions pràctiques

print("jo" in "tu i jo")  # in mira si el primer text es troba dins el segon
text:str = "    Un exemple "
print(text[1:15:2])  # slicing permet definir quins caràcters volem recuperar amb start, stop i step
llista: list[str] = text.split()  # split parteix la cadena per espais o pel caràcter indicat
print(llista)
text_recuperat:str = " ".join(llista) # join fa la feina inversa a split
print(text_recuperat)
print("text original:",text,". Amb strip:", text.strip(),". Però:",text)  
#strip retorna una cadena nova sense els espais d'inici i final o els caràcters indicats
# en aquest cas el text té a principi i final espais en blanc, com que coincideixen llavors strips elimina els extrems
print(text[4].isupper(),text[4].islower(),text[4].isalpha())  # verifiquem si és majúscula, minúscula o lletra
print(text.upper(),".Però:",text)  #retornem una cadena equivalent però majúscula
print(text.lower(),".Però:",text)  #retornem una cadena equivalent però  minúscula
# Out:
# True
#   neepe
# ['Un', 'exemple']
# Un exemple
# text original:     Un exemple  . Amb strip: Un exemple . Però:     Un exemple
# True False True
#     UN EXEMPLE  .Però:     Un exemple
#     un exemple  .Però:     Un exemple

# %% [markdown]
# ## 🧠 Python: llistes

# %%
l1: list[Any] = []  # Crea una llista buida
l1.append("gat")    # Afegeix un element al final de la llista
l1.append(2)

print(l1)

print("reverse:", l1.reverse(), l1)
# .reverse() inverteix l'ordre dels elements de la llista original.
# Retorna None perquè modifica la mateixa llista i no retorna una nova llista.

l2: list[int] = [4, 2, 8, 9, 1, 2, 4, 7]

print("sort:", l2.sort(), l2)
# .sort() ordena els elements de la llista original de menor a major.
# Retorna None perquè modifica la mateixa llista.

print("count:", l2.count(4), l2.count(8))
# .count(valor) retorna quantes vegades apareix un valor dins de la llista.

print("index:", l2.index(9))
# .index(valor) retorna l'índex de la primera aparició del valor indicat.

l2.remove(8)
# .remove(valor) elimina la primera aparició del valor indicat.
# Retorna None.

print("Després del remove:", l2)

print("pop:", l2.pop(5))
# .pop(index) elimina i retorna l'element que es troba a l'índex indicat.
# Si no indiquem cap índex, elimina i retorna l'últim element.

print("Després del pop:", l2)

print("in:", 9 in l2)
# in comprova si un valor es troba dins de la llista i retorna True o False.
# Out:
# ['gat', 2]
# reverse: None [2, 'gat']
# sort: None [1, 2, 2, 4, 4, 7, 8, 9]
# count: 2 1
# index: 7
# Després del remove: [1, 2, 2, 4, 4, 7, 9]
# pop: 7
# Després del pop: [1, 2, 2, 4, 4, 9]
# in: True

# %% [markdown]
# ### Matrius

# %%
m = [[1,2,3],[4,5,6],[7,8,9]]
print(m[0]) # índex 0 de la matriu m
print(m[1][1]) # element a l'índex 1 de l'índex 1 de la matriu m
# Out:
# [1, 2, 3]
# 5

# %% [markdown]
# ## 🧠 Python: diccionaris

# %%
persones = {"33998877":"John Cooper","88996644":"Elizabeth Carl","34896745":"Erik Peters"}

def digues_nom(dni:str) -> str:
    return persones[dni] # dins de la llista de persones, retorna el que té el dni indicat

# %%
digues_nom("88996644")
# Out:
# 'Elizabeth Carl'

# %% [markdown]
# ## 🧠 Python: referències

# %%
a:int = 4
b:int = 5
c:int = 6
print(id(a), id(b), id(c))  
d:str = "banana"
e:str = "banana"
print(id(d),id(e))
f:list[int] = [1, 2, 3]
g:list[int] = [1, 2, 3]
print(id(f),id(g)) 

# id() és un identificador de les variables, que són objectes en espais en memòria
# donat l'exemple f,g: aquestes tenen els mateixos valors però els seus identificadors són diferents
# f == g però id(f) != id(g)
# Out:
# 94007307070256 94007307070288 94007307070320
# 140380273412736 140380273412736
# 140380269986048 140380271762496

# %% [markdown]
# ## 🧠 Python: còpia profunda de variables

# %%
a:list[int] = [1, 2, 3]
b:list[int] = a # a i b tenen el mateix objecte llista
print(a,b,id(a),id(b)) # per tant coincideixen el identificadors
b[2] = 4
print(a) # mostren els mateixos valors 
print(b)

print()
a:list[int] = [1, 2, 3]
b:list[int] = a[:]  # b ja no apunta a "a", n'ha fet una còpia profunda ("clon")
print(a,b,id(a),id(b)) # els identificadors no coincideixen ja que no són el mateix objecte llista
b[2] = 4 # mostren diferents valors
print(a)
print(b)
# Out:
# [1, 2, 3] [1, 2, 3] 140380270452800 140380270452800
# [1, 2, 4]
# [1, 2, 4]
#
# [1, 2, 3] [1, 2, 3] 140380271569024 140380270444160
# [1, 2, 3]
# [1, 2, 4]

# %% [markdown]
# ## 🧠 Python: tuples

# %%
t: tuple = (1,2,3,4)
# tuple és com una llista però immutable: per tant, no podem modificar l'objecte existent
print(t[3]) 
print(t[2:4])

t1: tuple = ("gat",4,"gos")
print(t1)

t.append(5)  # Error 
t[0]="canari" # Error
# Out:
# 4
# (3, 4)
# ('gat', 4, 'gos')

# %% [markdown]
# ## 🧠 Python: biblioteques externes

# %%
import platform

x = platform.system()
print(x)
# Out:
# Linux

# %%
import math

a:float = 4.5
b:int = 3
c:int = 2
d:int = 4

print(math.ceil(a))  # retorna l'enter més proper major que el nombre donat
print(math.cos(0.5)) # retorna  el cosinus. Hi ha totes les funcions trigonomètriques
print(math.sqrt(d))  # calcula l'arrel quadrada
# Out:
# 5
# 0.8775825618903728
# 2.0

# %%
pow(3,2)
# Out:
# 9

# %% [markdown]
# Aquesta llista de problemes i solucions ha estat preparada amb l'ajut de ChatGPT 3.5, i revisada i adaptada per Mireia Ribera. I ha estat revisada a l'agost de 2026, amb l'ajut de Copilot.
