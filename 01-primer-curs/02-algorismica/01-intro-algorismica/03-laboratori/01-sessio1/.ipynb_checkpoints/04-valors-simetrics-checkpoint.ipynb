# %% [markdown]
# Aquest notebook forma part dels continguts teòrics dels problemes de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a></p>
#
# Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>

# %%
from __future__ import annotations

# %% [markdown]
# ## ✍️ Valors simètrics respecte d’un centre

# %% [markdown]
# Donada una llista d'enters i un valor `centre`, troba totes les parelles de valors diferents de posició que queden a la mateixa distància del centre, és a dir, parelles `(a, b)` que compleixen
#
# $$a-centre = centre-b.$$
#
# Retorna cada parella amb el valor menor primer i evita duplicats. Busca una solució d'ordre $O(n\log n)$ o millor.

# %% [markdown]
# ### 🧠 Tasca

# %%
def parelles_simetria(valors: list[int], centre: int) -> list[tuple[int, int]]:
    """Retorna parelles simètriques respecte del centre."""
    pass

# %% [markdown]
# ### ✅ Asserts públics

# %%
assert parelles_simetria([14, 2, 9, 6, 18, 10], 10) == [(2, 18), (6, 14)]
assert parelles_simetria([1, 4, 7, 10, 13], 7) == [(1, 13), (4, 10)]
assert parelles_simetria([3, 8, 12], 7) == []

# %% [markdown]
# ### 📊 Complexitat
#
# Indica i justifica la complexitat temporal i espacial de la solució.

# %% [markdown]
# ## ⭐ Repte

# %% [markdown]
# Retorna les **posicions originals** de les parelles, no els valors. Si hi ha duplicats, cada posició només pot participar una vegada.

# %%
def indexs_simetria(valors: list[int], centre: int) -> list[tuple[int, int]]:
    """Retorna parelles d'índexs originals amb valors simètrics."""
    pass

# %% [markdown]
# ### ✅ Asserts públics del repte

# %%
assert indexs_simetria([14, 2, 9, 6, 18, 10], 10) == [(0, 3), (1, 4)]

# %% [markdown]
# Aquesta llista de problemes i solucions ha estat preparada amb l'ajut de ChatGPT 3.5, i revisada i adaptada per Mireia Ribera. I ha estat revisada a l'agost de 2026, amb l'ajut de Copilot.
