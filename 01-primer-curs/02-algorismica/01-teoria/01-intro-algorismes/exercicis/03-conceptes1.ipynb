# %% [markdown]
# <div id="capcalera">
# <p >Aquest notebook complementa els continguts teòrics de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a></p>
#
# <p>Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>
#
# </div>

# %% [markdown]
# # <span class="tema">Introducció a l'algorísmica</span><br/> 📘Conceptes inicials 1

# %% [markdown]
#  ## 🧠 Aquí tens una funció en la que pots veure diversos elements del llenguatge:
#
# + comentaris,
# + variables,
# + assignacions,
# + iteracions,
# + entrada de dades des del teclat,
# + crida,
# + etc.

# %%
def comportament_caotic() -> None:
    """Comportament caòtic."""
    print("Aquesta funció implementa un comportament caòtic")
    x: float = float(input("Entra un nombre entre 0 i 1: "))
    for i in range(10):
        x = 3.9 * x * (1 - x)
        print(x)


comportament_caotic()
# Out:
# 0.975
# 0.09506250000000008
# 0.33549992226562525
# 0.8694649252590003
# 0.44263310911310905
# 0.962165255336889
# 0.1419727793616139
# 0.4750843861996143
# 0.9725789275369049
# 0.1040097132674683

# %% [markdown]
# ## ✍️ Pregunta 1
# Com s'anomena aquesta funció? quines variables es fan servir dins el codi?

# %%
# Posa aquí la teva resposta

# %% [markdown]
# ## ✍️ Pregunta 2
# Si x = 5, què valdrà l'expressió "3.9 * x * (1-x)"? usa l'intèrpret de Python per respondre.

# %% [markdown]
# ## ✍️ Pregunta 3
# Dins la funció hi ha alguna assignació d'entrada? reprodueix el codi a la casella següent i després executa la casella.

# %% [markdown]
# ## ✍️ Exercici 1
# Completa la funció següent amb el codi i amb comentaris explicant el que fa. Fixa't en l'exemple anterior

# %%
def hola(persona:str) -> None:
    
    
    
    print("Hola", persona)

# %% [markdown]
# ## ✍️ Exercici 2
# Converteix la funció anterior en una funció. Fes una crida i imprimeix el resultat.
