# %% [markdown]
# Aquest notebook forma part dels continguts teòrics dels problemes de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a></p>
#
# Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>

# %% [markdown]
# # 📘 <span class="tema">(Python)</span> Pràctica dels conceptes inicials

# %% [markdown]
# ## ✍️ 1. Completar funcions

# %%
## Completa les funcions següents segons les indicacions donades.
# Després crida-les i comprova que funcionen.


def      (nom: str) -> None:  # falta el nom de la funció
    """
    Mostra un nom per pantalla.

    Parameters
    ----------
    nom : str
        Nom que es vol mostrar.

    Returns
    -------
    None
        La funció mostra el nom per pantalla.
    """
    print(nom)


def calcul(x: int, y: int) -> None:
    """
    Fa una operació amb dos nombres enters i en mostra el resultat.

    Parameters
    ----------
    x : int
        Primer nombre.
    y : int
        Segon nombre.

    Returns
    -------
    None
        La funció mostra el resultat per pantalla.
    """
    # Tria l'operació que s'ha de fer amb x i y.
    pass


def calcul_per_teclat() -> None:
    """
    Demana dos nombres enters i en mostra el resultat d'un càlcul.

    Returns
    -------
    None
        La funció mostra el resultat per pantalla.
    """
    x: int = int(input("Digues un nombre: "))
    y: int            # completa-ho
    # Demana un segon nombre i guarda'l a y.
    # Després mostra el producte de x i y.
    print (f"El producte de {x} i {y} és {x * y}")


def elevat_a_3(n: int) -> None:
    """
    Mostra un nombre elevat al cub.

    Parameters
    ----------
    n : int
        Nombre que es vol elevar al cub.

    Returns
    -------
    None
        La funció mostra el resultat per pantalla.
    """
    print (n 3) # Com es feia la potència?

# %%
                    # aquí falta una crida

# %%
calcul(43, 2)

# %%
calcul_per_teclat()

# %%
elevat_a_3(5)

# %%
# Corregeix, si cal, les següents instruccions

print 3
print "hola"
print(3)
print(hola)

# %% [markdown]
# ## ✍️ 2. Noms de variables i funcions
#
# Per a cadascun dels identificadors següents, indica:
#
# 1. si és un nom **vàlid en Python**;
# 2. si segueix les convencions de **PEP 8** per a noms de variables o
#    funcions.
#
# ```text
# Hola
# FuncioMagnifica
# 1que_vol
# funcio magnifica
# funcio_magnifica
# funcio-magnifica
# while
# CALCUL
# ```
#
# Recorda que una cosa és que un identificador sigui acceptat pel llenguatge
# i una altra que segueixi les convencions d'estil.
#
# ### Referències
#
# - [Python 3.14 — Identifiers and keywords](https://docs.python.org/3.14/reference/lexical_analysis.html#identifiers)
# - [PEP 8 — Naming Conventions](https://peps.python.org/pep-0008/#naming-conventions)

# %% [markdown]
# ## ✍️ 3. El paràmetre `end` de `print()`
#
# Investiga què fa el paràmetre `end` de `print()`.
#
# Experimenta, per exemple, amb:
#
# ```python
# print("Hola", end="")
# print("Món")
# ```
#
# i compara el resultat amb:
#
# ```python
# print("Hola")
# print("Món")
# ```
#
# Explica amb les teves paraules què canvia i quin és el valor d'`end`
# que `print()` utilitza per defecte.

# %% [markdown]
# ## ✍️ 4. Input i tipus de dades

# %%
# Posa les instruccions per demanar la dada que s'indica seguint els patrons.
# Comprova de quin tipus és la variable resultant.

nom: str = input("Digues el teu nom: ")
type(nom)  # Per defecte, input() sempre retorna una cadena.

x: int = int(input("Digues la teva edat: "))
# Si volem llegir un enter, convertim la cadena amb int().
type(x)

# %%
# Demana la ciutat on viu.

# %%
# D.demana l'alçada.

# %%
# Demana quants germans i/o germanes té.

# %%
# Demana l'idioma preferent.

# %%
# Escriu una funció per intercanviar els valors de quatre variables.
#
# Inicialment:
# x = 4
# y = 5
# w = 6
# z = 7
#
# Al final has d'aconseguir:
# x = 7
# y = 4
# w = 5
# z = 6

# %% [markdown]
# ## ✍️ 5. Iteracions
#
# A partir del model següent, canvia els arguments de range() per mostrar els valors demanats.

# %%
# Model, mostra els valors de 2 a 10 en salts de 3 en 3

for i in range (2, 10, 3):
    print(i)

# %%
# Copia el model i canvia els valors per a que mostri 0 a 5 de 1 en 1

# %%
# Pots simplificar el codi de l'anterior casella amb els mateixos resultats?

# %%
# Copia el model i canvia els valors per a que es mostri 8,6,4

# %% [markdown]
# ## ✍️ 6. Exercici final
#
# Escriu una funció que pregunti a l'usuari algunes dades personals i després
# les mostri per pantalla de manera ordenada.
#
# La funció ha de demanar, com a mínim:
#
# - el nom;
# - la ciutat;
# - l'edat;
# - l'alçada.
#
# Converteix cada entrada al tipus adequat.
#
# Utilitza una **f-string** per mostrar el resultat final.

# %%
def mostrar_dades_personals() -> None:
    """
    Demana diverses dades personals i les mostra de manera ordenada.

    Returns
    -------
    None
        La funció mostra les dades introduïdes per l'usuari.
    """
    pass

# %% [markdown]
# Aquesta llista de problemes i solucions ha estat preparada amb l'ajut de ChatGPT 3.5, i revisada i adaptada per Mireia Ribera. I ha estat revisada a l'agost de 2026, amb l'ajut de Copilot.
