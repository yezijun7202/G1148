# %% [markdown]
# <div id="capcalera">
# <p >Aquest notebook complementa els continguts teòrics de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a></p>
#
# <p>Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>
#
# </div>

# %% [markdown]
# # <span class="tema">Introducció a l'algorísmica</span><br/> 📘Conceptes inicials 2

# %% [markdown]
# ## 🧠 Assignacions simultànies

# %% [markdown]
# ### ✍️ Pregunta 1
# Executa la següent cella i després canvia els valors. Explica què passa.

# %%
x: int = 3
y: int = 4
x = y
y = x

print(x, y)

# %% [markdown]
# ### ✍️ Pregunta 2
# Executa la següent cella i després canvia els valors. Explica què passa.

# %%
x: int = 3
y: int = 4
x, y = y, x

print(x, y)

# %% [markdown]
# ### ✍️Exercici 1
# T'atreveixes amb tres variables? Escriu el codi per fer un intercanvi entre tres variables x, y, z

# %%
print(x,y,z)

# %% [markdown]
# ## 🧠 Iteracions

# %% [markdown]
# ### ✍️ Exercici 2
# Experimenta amb les següents iteracions, canviant el valors dels literals.
#
# Abans de res però fes una còpia dels valors originals per no perdre'ls!!

# %%
for i in range(10):
    print(i, end=" ")

# %%
for j in [0,1,2,3]:
    print(j*j)
