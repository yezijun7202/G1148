# %% [markdown]
# Aquest notebook forma part dels continguts teòrics dels problemes de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a></p>
#
# Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>

# %% [markdown]
# # 📘 Python - Caràcters i cadenes

# %% [markdown]
# ## Representació de caràcters
#
# ### Documentació Python de referència
#
# - [`chr()` — Built-in Functions](https://docs.python.org/3.14/library/functions.html#chr)
# - [`ord()` — Built-in Functions](https://docs.python.org/3.14/library/functions.html#ord)
#
# Els ordinadors representen els caràcters mitjançant valors numèrics.
#
# **ASCII** és un sistema històric que defineix 128 caràcters: lletres llatines
# sense accents, dígits, signes de puntuació i caràcters de control.
#
# Alguns codis ASCII són:
#
# | Binari | Decimal | Hex | Representació |
# |---|---:|---:|---|
# | 00100000 | 32 | 20 | Espai en blanc |
# | 01000001 | 65 | 41 | A |
# | 01000010 | 66 | 42 | B |
# | 01000011 | 67 | 43 | C |
# | 01000100 | 68 | 44 | D |
# | 01000101 | 69 | 45 | E |
# | 01000110 | 70 | 46 | F |
# | 01000111 | 71 | 47 | G |
# | 01001000 | 72 | 48 | H |
# | 01001001 | 73 | 49 | I |
# | 01001010 | 74 | 4A | J |
# | 01001011 | 75 | 4B | K |
# | 01001100 | 76 | 4C | L |
# | 01001101 | 77 | 4D | M |
# | 01001110 | 78 | 4E | N |
# | 01001111 | 79 | 4F | O |
# | 01010000 | 80 | 50 | P |
# | 01010001 | 81 | 51 | Q |
# | 01010010 | 82 | 52 | R |
# | 01010011 | 83 | 53 | S |
# | 01010100 | 84 | 54 | T |
# | 01010101 | 85 | 55 | U |
# | 01010110 | 86 | 56 | V |
# | 01010111 | 87 | 57 | W |
# | 01011000 | 88 | 58 | X |
# | 01011001 | 89 | 59 | Y |
# | 01011010 | 90 | 5A | Z |
#
# | Binari | Decimal | Hex | Representació |
# |---|---:|---:|---|
# | 01011111 | 95 | 5F | _ |
# | 01100001 | 97 | 61 | a |
# | 01100010 | 98 | 62 | b |
# | 01100011 | 99 | 63 | c |
# | 01100100 | 100 | 64 | d |
# | 01100101 | 101 | 65 | e |
# | 01100110 | 102 | 66 | f |
# | 01100111 | 103 | 67 | g |
# | 01101000 | 104 | 68 | h |
# | 01101001 | 105 | 69 | i |
# | 01101010 | 106 | 6A | j |
# | 01101011 | 107 | 6B | k |
# | 01101100 | 108 | 6C | l |
# | 01101101 | 109 | 6D | m |
# | 01101110 | 110 | 6E | n |
# | 01101111 | 111 | 6F | o |
# | 01110000 | 112 | 70 | p |
# | 01110001 | 113 | 71 | q |
# | 01110010 | 114 | 72 | r |
# | 01110011 | 115 | 73 | s |
# | 01110100 | 116 | 74 | t |
# | 01110101 | 117 | 75 | u |
# | 01110110 | 118 | 76 | v |
# | 01110111 | 119 | 77 | w |
# | 01111000 | 120 | 78 | x |
# | 01111001 | 121 | 79 | y |
# | 01111010 | 122 | 7A | z |
#
# Actualment, Python treballa amb **Unicode**, que permet representar caràcters
# de pràcticament tots els sistemes d'escriptura.
#
# Una cadena `str` de Python és una seqüència de **punts de codi Unicode**.
# UTF-8, en canvi, és una de les codificacions que permet convertir aquests
# caràcters en bytes per emmagatzemar-los o transmetre'ls.
#
# Les funcions `chr()` i `ord()` permeten passar d'un punt de codi al caràcter
# corresponent i viceversa:
#
# - `chr(97)` retorna `"a"`
# - `ord("a")` retorna `97`

# %%
# Exemple

print(chr(76))
print(ord('z'))

# %% [markdown]
# ## ✍️ 1. Exercici 1: chr
#
# Mira la taula de l'ASCII i amb la instrucció chr mostra la lletra t

# %% [markdown]
# ## ✍️ 2. Exercici 2: ord
#
# Amb la instrucció ord, mostra el codi de la lletra m. Verifica'l a la taula ASCII. És el mateix que el de la M?

# %% [markdown]
# ## Cadenes de text (`str`)

# %% [markdown]
# A Python, el text es representa mitjançant objectes de tipus `str`
# (*strings* o cadenes de text).
#
# Una cadena és una **seqüència immutable de caràcters Unicode**. Com passa
# amb altres seqüències, cada element té una posició o índex i podem utilitzar
# operacions com:
#
# immutable: el valor de l'objecte no és modificable, on una variable pren un valor objecte fixe
#
# paraula = "CASA"
# paraula = "COSA"
#
# "CASA" i "COSA" són immutables, però podem reassignar el valor de la variable amb un altra cadena immutable
#
# - indexació: `cadena[0]`
# - *slicing*: `cadena[1:4]` -> trossejar la cadena indicant `[start:stop:step]`
# - longitud: `len(cadena)`
# - recorregut amb `for`
#
# La diferència important respecte d'una llista és que una cadena és
# **immutable**: un cop creada, no podem modificar directament un dels seus
# caràcters.

# %%
# Exemple
nom: str = "Eulàlia"

print(nom[0])

for i in range(0, len(nom), 2):
    print(nom[i], end="")

print()
print(nom[0:2])
print(nom[::-1])
# Out:
# E
# Ella
# Eu
# ailàluE

# %%
# però... no podem modificar els caràcters de la cadena, només podem reassignar la variable amb una altre valor
# nom[3] = "r"

# %% [markdown]
# ## Mètodes i funcions per a les cadenes
#
# Com que les cadenes de caràcters són una de les dades bàsiques amb les que es treballa, coneixerem algunes funcions que ens resultaran molt útils per aquest curs introductori.
#
# ### split
#
# Amb split puc separar una cadena en una llista amb els diferents trossets, indicant el separador.

# %%
# Exemple
"456.342.120".split(".") # Això ho converteix en una llista
# Out:
# ['456', '342', '120']

# %% [markdown]
# Si no indiquem cap separador, `split()` separa la cadena utilitzant els
# **espais en blanc** com a delimitadors.
#
# Això inclou espais, tabuladors o salts de línia, i diversos espais
# consecutius es tracten com un únic separador.

# %%
# Exemple
"un   dos   tres".split()
# Out:
# ['un', 'dos', 'tres']

# %% [markdown]
# ### join
#
# El mètode `join()` crea una cadena concatenant diverses cadenes i
# utilitzant com a separador la cadena sobre la qual invoquem el mètode.

# %%
# Exemple
paraules = ["una", "frase", "curta"]
" ".join(paraules)
# Out:
# 'una frase curta'

# %% [markdown]
# ### strip
#
# El mètode `strip()` retorna una còpia de la cadena eliminant caràcters
# del **principi i del final**.
#
# Sense arguments elimina els espais en blanc.

# %%
# Exemple
"introducció a Python".strip('nio')
# Out:
# 'troducció a Pyth'

# %%
" introducció   ".strip()
# Out:
# 'introducció'

# %% [markdown]
# Cal tenir en compte que "nio" no es tracta com una subcadena.
# strip() interpreta l'argument com un conjunt de caràcters i elimina
# qualsevol combinació d'aquests caràcters mentre apareguin als extrems.
#
# Si volem eliminar exactament un prefix o un sufix, podem utilitzar
# removeprefix() o removesuffix().

# %% [markdown]
# ## ✍️ 3. Exercici 3: Parts d'un text
#
# A partir de la cadena "El gos i el gat es barallen al carrer", amb operacions sobre strings aconsegueix els següents textos:
#
# - "el"
# - "rerrac"
# - "l gs l gt s brlln l crrr"

# %%
cadena: str = "El gos i el gat es barallen al carrer"

cadena_split = cadena.split()
print(cadena_split[3])

print(cadena[len(cadena)-1:-7:-1])

cadena_sense_vocals: str = ""

for lletra in cadena:
    vocals: list[str] = ["E","e","a","o","i"]
    if lletra not in vocals:
        print(lletra,end ="")
# Out:
# el
# rerrac
# l gs  l gt s brlln l crrr

# %% [markdown]
# ## ✍️ 4. Exercici 4: Unir paraules
#
# Fes un programa que demani tres paraules d'una frase a l'usuari i crei una única cadena amb elles i la mostri a pantalla.

# %%
expressio: str = "Avui fa bon temps, demà potser plou."

llistat_paraules: list[str] = []

for i in ["primera","segona","tercera"]:
    paraules: str = input(f"Introdueix una {i} paraula d'aquesta frase {expressio}: ")
    llistat_paraules += [paraules] 

# print(llistat_paraules)

llistat_sense_espais: list[str] = []

# vull treure primers els espais en blanc de les paraules dins el llistat_paraules
# després els afegeixo dins una altre llistat per mostrar la cadena formada per cada paraula de la llista amb un separador
for paraula in llistat_paraules:
    paraula = paraula.strip()
    llistat_sense_espais += [paraula]
    
llistat_join = " ".join(llistat_sense_espais)

print(llistat_join)
# Out:
# Introdueix una primera paraula d'aquesta frase Avui fa bon temps, demà potser plou.:   fa
# Introdueix una segona paraula d'aquesta frase Avui fa bon temps, demà potser plou.:  bon
# Introdueix una tercera paraula d'aquesta frase Avui fa bon temps, demà potser plou.:  temps
# fa bon temps

# %% [markdown]
# ### `islower()`, `isupper()` i `isalpha()`
#
# Aquests mètodes permeten comprovar característiques dels caràcters
# d'una cadena:
#
# - `islower()` retorna `True` si hi ha almenys un caràcter i si tots els caràcters estan en minúscula.
# - `isupper()` retorna `True` si hi ha almenys un caràcter i si tots aquests caràcters estan en majúscula.
# - `isalpha()` retorna `True` si la cadena no és buida i tots els seus
#   caràcters són alfabètics.
#
# `isalpha()` treballa amb caràcters **Unicode**, no només amb les lletres
# ASCII. Per exemple, lletres accentuades també poden ser alfabètiques.
#
# ### `lower()` i `upper()`
#
# - `lower()` retorna una nova cadena amb els caràcters convertits a minúscules.
# - `upper()` retorna una nova cadena amb els caràcters convertits a majúscules.
#
# Com que les cadenes són immutables, aquests mètodes **no modifiquen la
# cadena original**, sinó que retornen una cadena nova.

# %%
# Exemples

"HOLA".islower()
# Out:
# False

# %%
"HOLA".isupper()
# Out:
# True

# %%
"HOLA".isalpha()
# Out:
# True

# %%
"1HOLA".isalpha()
# Out:
# False

# %%
s: str = "HOLA".lower()
print(s)

# %%
t: str = "Hola".upper()
print(t)

# %% [markdown]
# ## ✍️ 5. Exercici 5: Què és?
#
# Escriu un petit programa que verifiqui si un string de longitud 1 donat és una lletra (minúscula o majúscula) i no és un dígit.

# %%
string: str = ""

while len(string) != 1 or string.isalpha() == False:
    string: str = input("Introdueix una sola lletra: ")
    if string.isalpha() == True:
        if len(string) == 1:
            print(f"{string} és una lletra.")
        else:
            print(f"{string} conté més d'una lletra")
    else:
        print(f"{string} no és una lletra.")
# Out:
# Introdueix una sola lletra:  H OLA
# H OLA no és una lletra.
# Introdueix una sola lletra:  HOLA
# HOLA conté més d'una lletra
# Introdueix una sola lletra:  H
# H  no és una lletra.
# Introdueix una sola lletra:  a
# a és una lletra.

# %% [markdown]
# ## ✍️ 6. Exercici 6. Paraules en majúscules
#
# Volem fer un programa que, donat un string qualsevol, ens retorni les paraules en majúscules i amb el nombre de lletres, tal com s'indica a l'exemple.

# %%
frase: str = input("Introdueix una frase qualsevol: ")

def frase_llarga(frase: str) -> None:
    """
    Mostra les paraules d'una frase en majúscules i la seva longitud.

    Parameters
    ----------
    frase : str
        Frase que conté les paraules que s'han de processar.

    Returns
    -------
    None
        La funció mostra el resultat per pantalla.
    """
    frase_split: list[str] = frase.split()

    frase_majuscula: str = ""
    for cadena in frase_split:
        print(f"{cadena.upper()} --> {len(cadena)} lletres")
        
        
    
frase_llarga(frase)
# Out:
# Introdueix una frase qualsevol:  Una frase qualsevol
# UNA --> 3 lletres
# FRASE --> 5 lletres
# QUALSEVOL --> 9 lletres

# %%
frase_llarga("Una frase qualsevol")
# Això hauria d'imprimir:

# UNA --> 3 lletres
# FRASE --> 5 lletres
# QUALSEVOL --> 9 lletres

# %% [markdown]
# ## Referències
# Les explicacions, exemples i exercicis s'han basat en les següents fonts:
#
# - [`chr()` — Built-in Functions](https://docs.python.org/3.14/library/functions.html#chr)
#   Converteix un punt de codi Unicode en el caràcter corresponent.
#
# - [`ord()` — Built-in Functions](https://docs.python.org/3.14/library/functions.html#ord)
#   Retorna el punt de codi Unicode corresponent a un caràcter.
#
# - [An Informal Introduction to Python — Strings](https://docs.python.org/3.14/tutorial/introduction.html#text)
#   Introducció a les cadenes, indexació i *slicing*.
#
# - [Text Sequence Type — `str`](https://docs.python.org/3.14/library/stdtypes.html#text-sequence-type-str)
#   Documentació completa del tipus `str`.
#
# - [String Methods](https://docs.python.org/3.14/library/stdtypes.html#string-methods)
#   Referència dels mètodes disponibles per treballar amb cadenes.
#
# - [Unicode HOWTO](https://docs.python.org/3.14/howto/unicode.html)
#   Introducció al funcionament d'Unicode i de les codificacions de text en Python.
#
# - Singh et al. “Time complexity of algorithms” dins Study tonight [http://www.studytonight.com/data-structures/time-complexity-of-algorithms]
#
# - Umesh V. Vazirani “Chapter 2: divide and conquer algorithms” [https://www.cs.berkeley.edu/~vazirani/algorithms/chap2.pdf]
#
# - Cormen, T. C., Leiserson, C. E., Rivest, R. L., & Stein, C. (2009). *Introduction to algorithms* (3rd ed.). Cambridge: The MIT Press. ISBN 9780262033848

# %% [markdown]
# Aquesta llista de problemes i solucions ha estat preparada amb l'ajut de ChatGPT 3.5, i revisada i adaptada per Mireia Ribera. I ha estat revisada a l'agost de 2026, amb l'ajut de Copilot.
