# %% [markdown]
# Aquest notebook forma part dels continguts teòrics dels problemes de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a></p>
#
# Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>

# %% [markdown]
# # 📘 Introducció a Python 📘 Notebook II
#
# Un cop vistes les expressions simples i els tipus de dades bàsics, en aquest
# notebook veurem:
#
# - les estructures condicionals;
# - les estructures iteratives `for` i `while`;
# - la definició i la crida de funcions.

# %% [markdown]
#  ## 🧠 Estructura condicional
#
# En Python utilitzem `if` per executar un bloc de codi només quan es compleix
# una determinada condició.
#
# Podem afegir:
#
# - `elif` per comprovar altres condicions si les anteriors són falses;
# - `else` per indicar què s'ha de fer si cap de les condicions anteriors
#   és certa.
#
# L'estructura general és:
#
# ```python
# if condicio1:
#     instruccions
# elif condicio2:
#     instruccions
# else:
#     instruccions
# ```
#
# Els blocs es defineixen mitjançant la **indentació**.

# %%
# Prova de canviar el valor assignat a la variable c1
c1: int = 25

if c1 > 24:
    print(f"{c1} és més gran que 24")
# Out:
# 25 és més gran que 24

# %%
# Prova de canviar el valor assignat a la variable c1
c1: int = 25

if c1 > 24:
    print(f"{c1} és més gran que 24")
else:
    print(f"{c1} no és més gran que 24")
# Out:
# 25 és més gran que 24

# %%
# Prova de canviar el valor assignat a la variable c1
c1: int = 25

if c1 > 24:
    print(f"{c1} és més gran que 24")
else:
    if c1 > 15:
        print(f"{c1} és més gran que 15 i menor o igual que 24")
    else:
        print(f"{c1} és menor o igual que 15")
# Out:
# 25 és més gran que 24

# %%
# elif equival a combinar conceptualment un else i un nou if
c1: int = 25

if c1 > 24:
    print(f"{c1} és més gran que 24")
elif c1 > 15:
    print(f"{c1} és més gran que 15 i menor o igual que 24")
else:
    print(f"{c1} és menor o igual que 15")
# Out:
# 25 és més gran que 24

# %% [markdown]
# ## ✍️ 1. Exercici 1: qualificació d'una prova
#
# Defineix una variable `qualificacio` amb un valor entre `0` i `10`.
#
# Escriu una estructura condicional que mostri:
#
# - si la qualificació és menor que `5`:
#   `"Has tret un XX, has suspès."`
# - de `5` a menys de `7`:
#   `"Has tret un XX, has aprovat."`
# - de `7` a menys de `9`:
#   `"Has tret un XX, has tret un notable."`
# - de `9` a `10`:
#   `"Has tret un XX, has tret un excel·lent."`
#
# Per a aquest exercici pots assumir que la qualificació sempre està entre
# `0` i `10`.

# %%
qualificacio:int = 9

if qualificacio <= 10 and qualificacio >= 9:
    print(f"Has tret un {qualificacio}, has tret un excel·lent.")
elif qualificacio < 9 and qualificacio >= 7:
    print(f"Has tret un {qualificacio}, has tret un notable.")
elif qualificacio < 7 and qualificacio >= 5:
    print(f"Has tret un {qualificacio}, has aprovat.")
else:
    print (f"Has tret un {qualificacio}, has suspès.")
# Out:
# Has tret un 9, has tret un excel·lent.

# %% [markdown]
#  ## 🧠 Estructures iteratives
#
# Les estructures iteratives permeten repetir un bloc d'instruccions.
#
# En Python utilitzarem principalment:
#
# - `for`: per recórrer els elements d'un iterable;
# - `while`: per repetir un bloc mentre es compleixi una condició.

# %% [markdown]
#  ## 🧠 Iteracions for

# %%
# En el cas del for, definim prèviament la seqüència de la iteració:
for i in range(5):
    print(f"El valor de i és {i}")
# Out:
# El valor de i és 0
# El valor de i és 1
# El valor de i és 2
# El valor de i és 3
# El valor de i és 4

# %%
# En el range podem definir el valor d'inici, el valor de parada i el salt

for i in range(1,10,2):
    print(f"El valor de i és {i}")
# Out:
# El valor de i és 1
# El valor de i és 3
# El valor de i és 5
# El valor de i és 7
# El valor de i és 9
# [1, 3, 5, 7, 9]

# %%
# La seqüència no té per què ser numèrica. 
# Per exemple, si volem imprimir totes les lletres diferents d'"a":

for c in 'Hola Món':
    if c != "a":
        print(f"{c}")

# %%
# També podem recorrer una llista

for animal in ["gat","gos","canari"]:
    print(f"Una mascota habitual és el {animal}")
# Out:
# Una mascota habitual és el gat
# Una mascota habitual és el gos
# Una mascota habitual és el canari

# %% [markdown]
# ## ✍️ 2. Exercici 2: taula de multiplicar
#
# Escriu el codi necessari per mostrar la taula de multiplicar del `5`,
# des de:
#
# `5 × 0`
#
# fins a:
#
# `5 × 10`.
#
# Utilitza una estructura `for`.

# %%
for i in range (11):
    print(f" 5 x {i} = {5 * i}")
# Out:
#  5 x 0 = 0
#  5 x 1 = 5
#  5 x 2 = 10
#  5 x 3 = 15
#  5 x 4 = 20
#  5 x 5 = 25
#  5 x 6 = 30
#  5 x 7 = 35
#  5 x 8 = 40
#  5 x 9 = 45
#  5 x 10 = 50

# %% [markdown]
#  ## 🧠 Iteracions While

# %%
# El while es repeteix mentre la seva condició sigui certa.
i: int = 0

while i < 5:
    print(f"{i} és menor que 5")
    i += 1  # Modifiquem i perquè la iteració pugui acabar.
# Out:
# 0 és menor que 5
# 1 és menor que 5
# 2 és menor que 5
# 3 és menor que 5
# 4 és menor que 5

# %%
# La condició del while pot combinar diverses expressions lògiques.
# La iteració s'atura quan la condició deixa de ser certa.
i: int = 0

while i < 5 and i != 3:
    print(f"{i} és menor que 5 i diferent de 3")
    i += 1
# Out:
# 0 és menor que 5 i diferent de 3
# 1 és menor que 5 i diferent de 3
# 2 és menor que 5 i diferent de 3

# %% [markdown]
# ## ✍️ 3. Exercici 3: cerca d'una edat més petita
#
# Defineix:
#
# 1. una variable `edat` amb la teva edat;
# 2. una llista `llista_edats` amb diverses edats.
#
# Escriu una iteració que vagi mostrant les edats de la llista en ordre i
# s'aturi quan trobi la primera edat que sigui més petita que `edat`.
#
# Pensa quina estructura és més adequada si volem deixar de recórrer la
# llista quan es compleixi aquesta condició.

# %%
edat: int = 19
llista_edats: list[int]= [10, 20, 30, 40, 50]
llista_invertida = llista_edats.reverse()

print()

# %%
## 🧠 Definició de funcions

En Python definim una funció amb la paraula reservada `def`.

Per exemple:

```python
def saludar() -> None:
    print("Hola")
```

Una funció pot rebre **paràmetres**:

```python
def saludar(nom: str) -> None:
    print(f"Hola {nom}")
```

i pot retornar un resultat mitjançant `return`:

```python
def sumar(a: int, b: int) -> int:
    return a + b
```

Si una funció arriba al final sense executar cap `return`, Python retorna
implícitament `None`.
# Out:
#   Cell In[15], line 3
#     En Python definim una funció amb la paraula reservada `def`.
#        ^
# SyntaxError: invalid syntax

# %%
# Definim una acció escriu_hola_mon que mostra el missatge "Hola Món".
def escriu_hola_mon() -> None:
    """
    Mostra el missatge "Hola Món" per pantalla.

    Returns
    -------
    None
        La funció només mostra un missatge.
    """
    print("Hola Món")



# Perquè l'acció s'executi, l'hem d'invocar.
escriu_hola_mon()
# Out:
# Hola Món

# %%
# Definim una funció suma_deu que retorna el valor rebut més 10.
def suma_deu(valor: int) -> int:
    """
    Suma 10 a un nombre enter.

    Parameters
    ----------
    valor : int
        Nombre al qual es vol sumar 10.

    Returns
    -------
    resultat : int
        Valor original incrementat en 10.
    """
    return valor + 10


# Com que la funció retorna un valor, podem assignar-ne el resultat.
nou_numero: int = suma_deu(1)
print(nou_numero)
# Out:
# 11

# %% [markdown]
# ## ✍️ 4. Exercici 4: convertir els exercicis en funcions
#
# Reescriu els exercicis 1, 2 i 3 utilitzant funcions.
#
# Completa els esquelets de les cel·les següents.
#
# Recorda:
#
# - indicar els tipus dels paràmetres;
# - indicar el tipus retornat;
# - mantenir la docstring;
# - utilitzar `return` només quan la funció hagi de retornar un resultat.

# %%
def la_meva_nota(qualificacio: float) -> None:
    """
    Mostra el resultat textual corresponent a una qualificació.

    Parameters
    ----------
    qualificacio : float
        Qualificació de la prova, entre 0 i 10.

    Returns
    -------
    None
        La funció mostra el resultat per pantalla.
    """
    pass

# %%
def taula_multiplicar(numero: int) -> None:
    """
    Mostra la taula de multiplicar d'un nombre.

    Parameters
    ----------
    numero : int
        Nombre del qual es vol mostrar la taula de multiplicar.

    Returns
    -------
    None
        La funció mostra la taula per pantalla.
    """
    pass

# %%
def edat_mes_petita(
    edat: int,
    llista_edats: list[int],
) -> None:
    """
    Mostra les edats fins a trobar-ne una de més petita que l'edat donada.

    Parameters
    ----------
    edat : int
        Edat que s'utilitza com a referència.
    llista_edats : list[int]
        Llista d'edats que es vol recórrer.

    Returns
    -------
    None
        La funció mostra les edats durant el recorregut.
    """
    pass

# %% [markdown]
#  ## 🧠 Observació
#
# Les variables i funcions definides en cel·les que ja hem executat continuen
# disponibles en les cel·les posteriors perquè el **kernel manté l'estat de
# la sessió**.
#
# Per tant, podem utilitzar una funció definida anteriorment sense tornar-la
# a definir.
#
# Cal recordar, però, que l'ordre d'execució de les cel·les és important.
# Si reiniciem el kernel, haurem de tornar a executar les cel·les que
# defineixen les funcions que necessitem.

# %%
# Podem, per exemple, combinar les dues funcions anteriors.
for _ in range(suma_deu(2)):
    escriu_hola_mon()
# Out:
# Hola Món
# Hola Món
# Hola Món
# Hola Món
# Hola Món
# Hola Món
# Hola Món
# Hola Món
# Hola Món
# Hola Món
# Hola Món
# Hola Món

# %% [markdown]
#  ## 📘 Referències
#
# Documentació oficial de Python 3.14:
#
# - [More Control Flow Tools](https://docs.python.org/3.14/tutorial/controlflow.html)
# - [Defining Functions](https://docs.python.org/3.14/tutorial/controlflow.html#defining-functions)
# - [The `range()` Function](https://docs.python.org/3.14/tutorial/controlflow.html#the-range-function)
# - [Type hints](https://docs.python.org/3.14/library/typing.html)

# %% [markdown]
# Aquesta llista de problemes i solucions ha estat preparada amb l'ajut de ChatGPT 3.5, i revisada i adaptada per Mireia Ribera. I ha estat revisada a l'agost de 2026, amb l'ajut de Copilot.
