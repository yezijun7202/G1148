# %% [markdown]
# - Escriu una funció que retorni la multiplicació de tres nombres enters.
# - Escriu una altra funció que mostri per pantalla 5 vegades “hola” i retorni “molt de gust”
# - Usa el mètode .count de str per saber quantes “a” hi ha en una paraula

# %%
def funcio1(a: int, b:int, c:int) -> int:

    return a * b * c

print(funcio1(1,2,3))
print()

def funcio2(cadena: str) -> str:

    print (cadena * 5)

    return "molt de gust"

print(funcio2("hola"))


print()
def funcio3(paraula: str) -> int:

    a: int = paraula.count("a")

    return a

print (funcio3("hola"))
# Out:
# 6
#
# holaholaholaholahola
# molt de gust
#
# 1
